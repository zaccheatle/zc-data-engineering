# %% [markdown]
# # Data Pipeline Portfolio Project

# %% [markdown]
# ### **Objective**: build a data engineering pipeline to regularly transform a messy database into a clean source of truth for an analytics team.
# ### **Data Source:** Cademycode customer data
# ### **Data Format**: sqlite3 Database
# #### **Author**: Zac Cheatle

# %%
# import dependencies
import os
import pandas as pd
import numpy as np
import json
import sqlite3
import logging

# set pandas column width
pd.set_option('display.max_colwidth', None)

# %%
# connect to sqlite3 db 

con = sqlite3.connect('cademycode.db')

curs = con.cursor()

# %%
# view tables

curs.execute('''SELECT name FROM sqlite_master WHERE type='table';''').fetchall()
# Out:
# [('cademycode_students',),
#  ('cademycode_courses',),
#  ('cademycode_student_jobs',)]

# %%
# import tables to dataframes (could do this with a loop but since only 3 tables going to do this 1 by 1)

# students
students = pd.read_sql_query('SELECT * FROM cademycode_students', con)
students.head(5)
# Out:
#    uuid             name         dob sex  \
# 0     1  Annabelle Avery  1943-07-03   F
# 1     2      Micah Rubio  1991-02-07   M
# 2     3       Hosea Dale  1989-12-07   M
# 3     4     Mariann Kirk  1988-07-31   F
# 4     5  Lucio Alexander  1963-08-31   M
#
#                                                                                                       contact_info  \
# 0   {"mailing_address": "303 N Timber Key, Irondale, Wisconsin, 84736", "email": "annabelle_avery9376@woohoo.com"}
# 1                 {"mailing_address": "767 Crescent Fair, Shoals, Indiana, 37439", "email": "rubio6772@hmail.com"}
# 2  {"mailing_address": "P.O. Box 41269, St. Bonaventure, Virginia, 83637", "email": "hosea_dale8084@coldmail.com"}
# 3             {"mailing_address": "517 SE Wintergreen Isle, Lane, Arkansas, 82242", "email": "kirk4005@hmail.com"}
# 4  {"mailing_address": "18 Cinder Cliff, Doyles borough, Rhode Island, 73737", "email": "alexander9810@hmail.com"}
#
#   job_id num_course_taken current_career_path_id time_spent_hrs
# 0    7.0              6.0                    1.0           4.99
# 1    7.0              5.0                    8.0            4.4
# 2    7.0              8.0                    8.0           6.74
# 3    6.0              7.0                    9.0          12.31
# 4    7.0             14.0                    3.0           5.64

# %%
# import tables to dataframes

# courses
courses = pd.read_sql_query('SELECT * FROM cademycode_courses', con)
courses.head(5)
# Out:
#    career_path_id      career_path_name  hours_to_complete
# 0               1        data scientist                 20
# 1               2         data engineer                 20
# 2               3          data analyst                 12
# 3               4  software engineering                 25
# 4               5      backend engineer                 18

# %%
# import tables to dataframes

# student jobs
student_jobs = pd.read_sql_query('SELECT * FROM cademycode_student_jobs', con)
student_jobs.head(5)
# Out:
#    job_id        job_category  avg_salary
# 0       1           analytics       86000
# 1       2            engineer      101000
# 2       3  software developer      110000
# 3       4            creative       66000
# 4       5  financial services      135000

# %% [markdown]
# ## Data Prep

# %% [markdown]
# #### Shape

# %%
students.shape
# Out:
# (5000, 9)

# %%
courses.shape
# Out:
# (10, 3)

# %%
student_jobs.shape
# Out:
# (13, 3)

# %% [markdown]
# #### Column clean up

# %%
# split contact_info column into separate email and address columns
students['contact_info'] = students['contact_info'].apply(lambda x: json.loads(x) if isinstance(x, str) else x)
students['mailing_address'] = students['contact_info'].apply(lambda x: x.get('mailing_address') if isinstance(x, dict) else None)
students['email'] = students['contact_info'].apply(lambda x: x.get('email') if isinstance(x, dict) else None)

# split up mailing address into separate columns
students[['address', 'city', 'state', 'zip']] = students['mailing_address'].str.extract(r'^(.*),\s*([\w\s]+),\s*([\w\s]+),\s*(\d+)$')

# %%
# drop original contact_info column
students = students.drop(columns=['mailing_address'])
students = students.drop(columns=['contact_info'])
students.head()
# Out:
#    uuid             name         dob sex job_id num_course_taken  \
# 0     1  Annabelle Avery  1943-07-03   F    7.0              6.0
# 1     2      Micah Rubio  1991-02-07   M    7.0              5.0
# 2     3       Hosea Dale  1989-12-07   M    7.0              8.0
# 3     4     Mariann Kirk  1988-07-31   F    6.0              7.0
# 4     5  Lucio Alexander  1963-08-31   M    7.0             14.0
#
#   current_career_path_id time_spent_hrs                           email  \
# 0                    1.0           4.99  annabelle_avery9376@woohoo.com
# 1                    8.0            4.4             rubio6772@hmail.com
# 2                    8.0           6.74     hosea_dale8084@coldmail.com
# 3                    9.0          12.31              kirk4005@hmail.com
# 4                    3.0           5.64         alexander9810@hmail.com
#
#                    address            city         state    zip
# 0         303 N Timber Key        Irondale     Wisconsin  84736
# 1        767 Crescent Fair          Shoals       Indiana  37439
# 2                      NaN             NaN           NaN    NaN
# 3  517 SE Wintergreen Isle            Lane      Arkansas  82242
# 4          18 Cinder Cliff  Doyles borough  Rhode Island  73737

# %% [markdown]
# #### Duplicates

# %%
students.duplicated().value_counts()
# Out:
# False    5000
# dtype: int64

# %%
courses.duplicated().value_counts()
# Out:
# False    10
# dtype: int64

# %%
student_jobs.duplicated().value_counts()
# Out:
# False    10
# True      3
# dtype: int64

# %%
student_jobs=student_jobs.drop_duplicates(keep='last')

# %%
student_jobs.duplicated().value_counts()
# Out:
# False    10
# dtype: int64

# %% [markdown]
# #### Missing Values

# %%
students.isnull().sum()
# Out:
# uuid                        0
# name                        0
# dob                         0
# sex                         0
# job_id                      5
# num_course_taken          251
# current_career_path_id    471
# time_spent_hrs            471
# email                       0
# address                    77
# city                       77
# state                      77
# zip                        77
# dtype: int64

# %%
# drop all rows with a null value
students = students.dropna()

# %%
students.shape
# Out:
# (4224, 13)

# %%
courses.isnull().sum()
# Out:
# career_path_id       0
# career_path_name     0
# hours_to_complete    0
# dtype: int64

# %%
student_jobs.isnull().sum()
# Out:
# job_id          0
# job_category    0
# avg_salary      0
# dtype: int64

# %% [markdown]
# #### Data Types

# %%
students.dtypes
# Out:
# uuid                       int64
# name                      object
# dob                       object
# sex                       object
# job_id                    object
# num_course_taken          object
# current_career_path_id    object
# time_spent_hrs            object
# email                     object
# address                   object
# city                      object
# state                     object
# zip                       object
# dtype: object

# %%
### set datatypes

dtype_dict = {'uuid':'int16',
              'name':'string', 
              'dob':'datetime64[ns]', 
              'sex':'category', 
              'job_id':'float16', 
              'num_course_taken':'float16', 
              'current_career_path_id':'float16', 
              'time_spent_hrs':'float16',
              'email':'string',
              'address':'string',
              'city':'string',
              'state':'category',
              'zip': 'string'}

students = students.astype(dtype_dict)
students.dtypes
# Out:
# uuid                               int16
# name                              string
# dob                       datetime64[ns]
# sex                             category
# job_id                           float16
# num_course_taken                 float16
# current_career_path_id           float16
# time_spent_hrs                   float16
# email                             string
# address                           string
# city                              string
# state                           category
# zip                               string
# dtype: object

# %%
students['num_course_taken'] = students['num_course_taken'].astype(int)
students['job_id'] = students['job_id'].astype(int)
students['current_career_path_id'] = students['current_career_path_id'].astype(int)
students.head()
# Out:
#    uuid              name        dob sex  job_id  num_course_taken  \
# 0     1   Annabelle Avery 1943-07-03   F       7                 6
# 1     2       Micah Rubio 1991-02-07   M       7                 5
# 3     4      Mariann Kirk 1988-07-31   F       6                 7
# 4     5   Lucio Alexander 1963-08-31   M       7                14
# 5     6  Shavonda Mcmahon 1989-10-15   F       6                10
#
#    current_career_path_id  time_spent_hrs                           email  \
# 0                       1        4.988281  annabelle_avery9376@woohoo.com
# 1                       8        4.398438             rubio6772@hmail.com
# 3                       9       12.312500              kirk4005@hmail.com
# 4                       3        5.640625         alexander9810@hmail.com
# 5                       3       10.117188       shavonda5863@coldmail.com
#
#                    address            city         state    zip
# 0         303 N Timber Key        Irondale     Wisconsin  84736
# 1        767 Crescent Fair          Shoals       Indiana  37439
# 3  517 SE Wintergreen Isle            Lane      Arkansas  82242
# 4          18 Cinder Cliff  Doyles borough  Rhode Island  73737
# 5           P.O. Box 81591  Tarpon Springs       Montana  37057

# %%
courses.dtypes
# Out:
# career_path_id        int64
# career_path_name     object
# hours_to_complete     int64
# dtype: object

# %%
student_jobs.dtypes
# Out:
# job_id           int64
# job_category    object
# avg_salary       int64
# dtype: object

# %% [markdown]
# ## Export Cleaned Data

# %% [markdown]
# #### Create new sqlite3 database with cleaned tables

# %%
new_conn = sqlite3.connect('cleaned_cademycode.db')

students.to_sql('students', new_conn, index=False, if_exists='replace')
courses.to_sql('courses', new_conn, index=False, if_exists='replace')
student_jobs.to_sql('student_jobs', new_conn, index=False, if_exists='replace')
# Out:
# 10

# %% [markdown]
# #### Create csv with all tables merged together for analysts

# %%
students_courses = students.merge(courses, left_on='current_career_path_id', right_on='career_path_id', how='left')
cleaned_cademycode_data = students_courses.merge(student_jobs, on='job_id', how='left')
cleaned_cademycode_data.drop(['career_path_id'], axis=1, inplace=True)
cleaned_cademycode_data.head()
# Out:
#    uuid              name        dob sex  job_id  num_course_taken  \
# 0     1   Annabelle Avery 1943-07-03   F       7                 6
# 1     2       Micah Rubio 1991-02-07   M       7                 5
# 2     4      Mariann Kirk 1988-07-31   F       6                 7
# 3     5   Lucio Alexander 1963-08-31   M       7                14
# 4     6  Shavonda Mcmahon 1989-10-15   F       6                10
#
#    current_career_path_id  time_spent_hrs                           email  \
# 0                       1        4.988281  annabelle_avery9376@woohoo.com
# 1                       8        4.398438             rubio6772@hmail.com
# 2                       9       12.312500              kirk4005@hmail.com
# 3                       3        5.640625         alexander9810@hmail.com
# 4                       3       10.117188       shavonda5863@coldmail.com
#
#                    address            city         state    zip  \
# 0         303 N Timber Key        Irondale     Wisconsin  84736
# 1        767 Crescent Fair          Shoals       Indiana  37439
# 2  517 SE Wintergreen Isle            Lane      Arkansas  82242
# 3          18 Cinder Cliff  Doyles borough  Rhode Island  73737
# 4           P.O. Box 81591  Tarpon Springs       Montana  37057
#
#             career_path_name  hours_to_complete job_category  avg_salary
# 0             data scientist                 20           HR       80000
# 1          android developer                 27           HR       80000
# 2  machine learning engineer                 35    education       61000
# 3               data analyst                 12           HR       80000
# 4               data analyst                 12    education       61000

# %%
# create csv

cleaned_cademycode_data.to_csv('cleaned_cademycode_data', index=False)

# %%
#### commit and close db connections

con.close()

new_conn.commit()
new_conn.close()
